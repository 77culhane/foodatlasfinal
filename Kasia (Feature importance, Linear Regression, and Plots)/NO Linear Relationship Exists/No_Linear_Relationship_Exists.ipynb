# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
# Reading the csv file into a pandas DataFrame

df = pd.read_csv("unitedstatesdata.csv", encoding = 'utf8')
df.head()
# Out:
#    no_grocery_stores_2009  no_convenience_stores_2009  fast_food_no_2009  \
# 0                       6                          29                 30
# 1                      24                         119                112
# 2                       5                          14                 21
# 3                       6                          19                  7
# 4                       6                          31                 24
#
#    snap_benefits_2010_dollars_per_capita  adult_obesity_2008_percentage  \
# 0                                     17                             32
# 1                                     14                             26
# 2                                     28                             38
# 3                                     20                             32
# 4                                     19                             32
#
#    median_income_2015  SNAP_stores_2012  WIC_stores_2008  \
# ...

# %%
#  Checking the number of rows and columns in our dataset

df.shape
# Out:
# (3143, 26)

# %%
# 1. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='no_grocery_stores_2009',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 2. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='no_convenience_stores_2009',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 3. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='fast_food_no_2009',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 4. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='SNAP_stores_2012',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 5. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='WIC_stores_2008',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 6. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='Full_service_rest_2009',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 7. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='soda_sales_tax_2014',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 8. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='FOODINSEC_10_12',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 9. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='FOODINSEC_10_12',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 10. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='Rec_facilities_count_2009',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 11. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='Low_access_to_store_count_2010',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 12. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='Low_access_to_store_no_car_count_2010',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 13. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='Fast_food_expenditure_per_capita',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 14. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='SNAP_redemption_2012_dollars_per_store',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# TESTING THE 10 FEATUES SELECTED FROM THE FEATURE SELECTOR

#                      Specs         Score
#7      PCH_LACCESS_LOWI_10_15  1.546388e+08
#2       PCH_LACCESS_POP_10_15  1.539427e+08
#24  PCH_LACCESS_SENIORS_10_15  4.129976e+07
#0               LACCESS_POP10  3.322108e+07
#1               LACCESS_POP15  2.999279e+07
#27            LACCESS_WHITE15  2.477771e+07
#93             REDEMP_SNAPS12  1.336538e+07 Already tested. See #14.
#94             REDEMP_SNAPS16  1.238995e+07
#17            LACCESS_CHILD10  7.893209e+06
#31             LACCESS_HISP15  7.623096e+06

# %%
# 1. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='LACCESS_HISP15',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 2. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='LACCESS_CHILD10',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 3. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='REDEMP_SNAPS16',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 4. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='LACCESS_WHITE15',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 5. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='LACCESS_POP10',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 6. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='LACCESS_POP15',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 7. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='PCH_LACCESS_SENIORS_10_15',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 8. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='PCH_LACCESS_POP_10_15',y='adult_obesity_2008_percentage',color='blue')
plt.show()

# %%
# 9. Plotting data points to eyeball our dataset and see if we can manually find any relationship between the data

# RESULT: NO LINEAR RELATIONSHIP EXISTS

df.plot(kind='scatter',x='PCH_LACCESS_LOWI_10_15',y='adult_obesity_2008_percentage',color='blue')
plt.show()
