# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

# %%
food_atlas_df = pd.read_csv('datadownloadrevised.csv')

X = food_atlas_df.drop("PCT_OBESE_ADULTS08", axis=1)
y = food_atlas_df["PCT_OBESE_ADULTS08"]

# %%
plt.figure(figsize=(12,10))
corr = food_atlas_df.corr()
#seaborn.heatmap(corr, annot=True, cmap=plt.cm.Reds)
#plt.show()

# %%
corr_target = abs(corr["PCT_OBESE_ADULTS08"])

relevant_features = corr_target[corr_target>0.3]
relevant_features.sort_values(ascending=False)
# Out:
# PCT_OBESE_ADULTS08       1.000000
# PCT_OBESE_ADULTS13       0.780367
# PCT_DIABETES_ADULTS08    0.733262
# PCT_DIABETES_ADULTS13    0.673437
# PC_FSRSALES07            0.472710
# PC_SNAPBEN10             0.461935
# PCT_FREE_LUNCH09         0.457901
# PC_FSRSALES12            0.457687
# POVRATE15                0.452695
# PCT_NHBLACK10            0.448597
# MEDHHINC15               0.446062
# CHILDPOVRATE15           0.445416
# PC_SNAPBEN15             0.422989
# PCT_SNAP12               0.408578
# PCT_NSLP09               0.402856
# PCT_NSLP15               0.382982
# PCT_SBP09                0.369711
# FSRPTH14                 0.366512
# PCT_LACCESS_BLACK15      0.361851
# PERPOV10                 0.351441
# FSRPTH09                 0.346078
# PERCHLDPOV10             0.345644
# PCT_SNAP16               0.338043
# FOODINSEC_13_15          0.324910
# PCT_SBP15                0.323323
# VLFOODSEC_13_15          0.317785
# PCT_LACCESS_HHNV15       0.307266
# ...

# %%
ax1 = food_atlas_df.plot.scatter(x='PCT_OBESE_ADULTS08' , y='PCT_DIABETES_ADULTS08')

# %%
ax2 = food_atlas_df.plot.scatter(x='PCT_OBESE_ADULTS08' , y='PC_FSRSALES07')

# %%
ax3 = food_atlas_df.plot.scatter(x='PCT_OBESE_ADULTS08' , y='PC_SNAPBEN10')

# %%
ax3 = food_atlas_df.plot.scatter(x='PCT_OBESE_ADULTS08' , y='PCT_FREE_LUNCH09')

# %%
ax4 = food_atlas_df.plot.scatter(x='PCT_OBESE_ADULTS08' , y='POVRATE15')

# %%
ax4 = food_atlas_df.plot.scatter(x='PCT_OBESE_ADULTS08' , y='PCT_NHBLACK10')

# %%
ax5 = food_atlas_df.plot.scatter(x='PCT_OBESE_ADULTS08' , y='MEDHHINC15')

# %%
ax6 = food_atlas_df.plot.scatter(x='PCT_OBESE_ADULTS08' , y='CHILDPOVRATE15')

# %%
ax8 = food_atlas_df.plot.scatter(x='PCT_OBESE_ADULTS08' , y='PCT_NSLP09')

# %%
ax9 = food_atlas_df.plot.scatter(x='PCT_OBESE_ADULTS08' , y='PCT_LACCESS_BLACK15')

# %%
ax10 = food_atlas_df.plot.scatter(x='PCT_OBESE_ADULTS08' , y='FOODINSEC_13_15')
